# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.cluster import KMeans

plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

df = pd.read_csv("../data/maya-sites.csv")
X = df.loc[:, ["Latitude", "Longitude"]]
X.head()
# Out:
#     Latitude  Longitude
# 0  20.813087 -89.452460
# 1  19.900930 -90.325400
# 2  14.928033 -89.962406
# 3  17.075500 -89.939000
# 4  16.450000 -88.580000

# %%
kmeans = KMeans(n_clusters=6)
X["Cluster"] = kmeans.fit_predict(X)
X["Cluster"] = X["Cluster"].astype("category")

X.head()
# Out:
#     Latitude  Longitude Cluster
# 0  20.813087 -89.452460       3
# 1  19.900930 -90.325400       3
# 2  14.928033 -89.962406       5
# 3  17.075500 -89.939000       2
# 4  16.450000 -88.580000       2

# %%
sns.relplot(
    x="Longitude", y="Latitude", hue="Cluster", data=X, height=6,
);
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.
