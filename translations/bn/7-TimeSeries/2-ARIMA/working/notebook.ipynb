# %% [markdown]
# এই নোটবুকে, আমরা দেখাবো কীভাবে:
# - ARIMA টাইম সিরিজ পূর্বাভাস মডেলের জন্য টাইম সিরিজ ডেটা প্রস্তুত করা যায়
# - একটি সাধারণ ARIMA মডেল প্রয়োগ করে টাইম সিরিজে পরবর্তী HORIZON ধাপগুলোর পূর্বাভাস করা যায় (*t+1* থেকে *t+HORIZON* পর্যন্ত)
# - মডেল মূল্যায়ন করা যায়
#
# এই উদাহরণে ব্যবহৃত ডেটা GEFCom2014 পূর্বাভাস প্রতিযোগিতা থেকে নেওয়া হয়েছে। এটি ২০১২ থেকে ২০১৪ সালের মধ্যে ৩ বছরের ঘণ্টাভিত্তিক বিদ্যুৎ লোড এবং তাপমাত্রার মান নিয়ে গঠিত। কাজটি হলো ভবিষ্যতের বিদ্যুৎ লোডের মান পূর্বাভাস করা। এই উদাহরণে, আমরা দেখাবো কীভাবে শুধুমাত্র ঐতিহাসিক লোড ডেটা ব্যবহার করে এক ধাপ সময়ের পূর্বাভাস করা যায়।
#
# তাও হং, পিয়েরে পিনসন, শু ফ্যান, হামিদরেজা জারেইপুর, আলবার্তো ট্রোকোলি এবং রব জে. হাইন্ডম্যান, "সম্ভাব্য শক্তি পূর্বাভাস: গ্লোবাল এনার্জি পূর্বাভাস প্রতিযোগিতা ২০১৪ এবং তার পরবর্তী", ইন্টারন্যাশনাল জার্নাল অফ ফোরকাস্টিং, vol.32, no.3, pp 896-913, জুলাই-সেপ্টেম্বর, ২০১৬।

# %%
pip install statsmodels

# %% [markdown]
# ---
#
# **অস্বীকৃতি**:
# এই নথিটি AI অনুবাদ পরিষেবা [Co-op Translator](https://github.com/Azure/co-op-translator) ব্যবহার করে অনুবাদ করা হয়েছে। আমরা যথাসম্ভব সঠিক অনুবাদ প্রদানের চেষ্টা করি, তবে অনুগ্রহ করে মনে রাখবেন যে স্বয়ংক্রিয় অনুবাদে ত্রুটি বা অসঙ্গতি থাকতে পারে। মূল ভাষায় থাকা নথিটিকে প্রামাণিক উৎস হিসেবে বিবেচনা করা উচিত। গুরুত্বপূর্ণ তথ্যের জন্য, পেশাদার মানব অনুবাদ সুপারিশ করা হয়। এই অনুবাদ ব্যবহারের ফলে কোনো ভুল বোঝাবুঝি বা ভুল ব্যাখ্যা হলে আমরা দায়বদ্ধ থাকব না।
